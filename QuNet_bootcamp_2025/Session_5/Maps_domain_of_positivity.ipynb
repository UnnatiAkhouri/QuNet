# %% [markdown]
# This notebbook will for allow you to explore the domain of positivity of a density matrix. The domain of positivity is the set of all density matrices that are positive semi-definite. This means that the eigenvalues of the density matrix are non-negative. The domain of positivity is important because it is the set of all valid density matrices.
