# %%
# Add directory above current directory to path
import sys as SYS; SYS.path.insert(0, '..')

# for saving
import os

from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt

from src import setup
# setup.use_gpu()

# %%
from src.random_unitary import random_energy_preserving_unitary,random_unitary_in_subspace

# %%
random_energy_preserving_unitary(4).plot()

# %% [markdown]
# This is created by generating a random unitary of the size of each energy subspace and inserting it in to the right place of in the overall matrix.

# %%
random_unitary_in_subspace(4,1).plot()
