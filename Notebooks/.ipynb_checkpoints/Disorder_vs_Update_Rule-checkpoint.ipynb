# %%
# Add directory above current directory to path
import sys as SYS; SYS.path.insert(0, '..')
# for saving
import os
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from src import setup
# setup.use_gpu()

# %%
from src import ( 
    measurements as measure,
    density_matrix as DM,
    simulation as sim,
    orders,
    order_rules,
    random_unitary,
    simulation)
from Scripts import simulation_CLI as cleo

# %%
import matplotlib.animation as animation
# Add directory above current directory to path
import sys as SYS; SYS.path.insert(0, '../..')
import h5py
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from src import ket as ket
from src import density_matrix as DM
from collections import Counter
import matplotlib.cm as cm
from scipy.optimize import curve_fit
import sys as SYS; SYS.path.insert(0, '../..')
from Scripts import hdf5merge
import matplotlib.colors as mcolors

# %%
#hdf5merge.merge_hdf5_files("../data/random")
#hdf5merge.merge_hdf5_files("../data/greedy")
hdf5merge.merge_hdf5_files("../data/mimic_12_disorder")
#hdf5merge.merge_hdf5_files("../data/landscape_maximizes")
#hdf5merge.merge_hdf5_files("../data/strongest_maximizes")

# %%
newdata1_th = dict(h5py.File("../data/unnati_submit_12_therm_random/unnati_submit_12_therm_random.hdf5"))
newdata2_th = dict(h5py.File("../data/unnati_submit_12_therm_greedy/unnati_submit_12_therm_greedy.hdf5"))
newdata3_th = dict(h5py.File("../data/unnati_submit_12_therm_mimic/unnati_submit_12_therm_mimic.hdf5"))
newdata4_th = dict(h5py.File("../data/unnati_submit_12_therm_landmax/unnati_submit_12_therm_landmax.hdf5"))
newdata5_th = dict(h5py.File("../data/unnati_submit_12_therm_strong_max/unnati_submit_12_therm_strong_max.hdf5"))

newdata1_pure = dict(h5py.File("../data/unnati_submit_12_pure_random/unnati_submit_12_pure_random.hdf5"))
newdata2_pure = dict(h5py.File("../data/unnati_submit_12_pure_greedy/unnati_submit_12_pure_greedy.hdf5"))
newdata3_pure = dict(h5py.File("../data/unnati_submit_12_pure_mimic/unnati_submit_12_pure_mimic.hdf5"))
newdata4_pure = dict(h5py.File("../data/unnati_submit_12_pure_landmax/unnati_submit_12_pure_landmax.hdf5"))
newdata5_pure = dict(h5py.File("../data/unnati_submit_12_pure_strongmax/unnati_submit_12_pure_strongmax.hdf5"))

newdata1_v1 = dict(h5py.File("../data/unnati_submit_12_inhomo_v1_random/unnati_submit_12_inhomo_v1_random.hdf5"))
newdata2_v1 = dict(h5py.File("../data/unnati_submit_12_inhomo_v1_greedy/unnati_submit_12_inhomo_v1_greedy.hdf5"))
newdata3_v1 = dict(h5py.File("../data/unnati_submit_12_inhomo_v1_mimic/unnati_submit_12_inhomo_v1_mimic.hdf5"))
newdata4_v1 = dict(h5py.File("../data/unnati_submit_12_inhomo_v1_landmax/unnati_submit_12_inhomo_v1_landmax.hdf5"))
newdata5_v1 = dict(h5py.File("../data/unnati_submit_12_inhomo_v1_strong_max/unnati_submit_12_inhomo_v1_strong_max.hdf5"))

newdata1_v2 = dict(h5py.File("../data/unnati_submit_12_inhomo_v2_random/unnati_submit_12_inhomo_v2_random.hdf5"))
newdata2_v2 = dict(h5py.File("../data/unnati_submit_12_inhomo_v2_greedy/unnati_submit_12_inhomo_v2_greedy.hdf5"))
newdata3_v2 = dict(h5py.File("../data/unnati_submit_12_inhomo_v2_mimic/unnati_submit_12_inhomo_v2_mimic.hdf5"))
newdata4_v2 = dict(h5py.File("../data/unnati_submit_12_inhomo_v2_landmax/unnati_submit_12_inhomo_v2_landmax.hdf5"))
newdata5_v2 = dict(h5py.File("../data/unnati_submit_12_inhomo_v2_strongmax/unnati_submit_12_inhomo_v2_strongmax.hdf5"))

# %%
#newdata1 = dict(h5py.File("../data/random/random.hdf5"))
#newdata2 = dict(h5py.File("../data/greedy/greedy.hdf5"))
newdata3 = dict(h5py.File("../data/mimic_12_disorder/mimic_12_disorder.hdf5"))
#newdata4 = dict(h5py.File("../data/landscape_maximizes/landscape_maximizes.hdf5"))
#newdata5 = dict(h5py.File("../data/strongest_maximizes/strongest_maximizes.hdf5"))

# %%
def get_pops(data, n_qubits, connectivity,update_rule):
    #dimension 0 is each trial
    #dimension 1 is each time step
    #dimension 2 is each qubit
    result = []
    for trial in data[f'{n_qubits} qubits'][f'{connectivity} connectivity']['unitary energy subspace 1']:
        seed = trial.split(' ')[-1]
        dat = dict(data[f'{n_qubits} qubits'][f'{connectivity} connectivity']['unitary energy subspace 1'][f'unitary seed {seed}'][f'ordering seed {update_rule}']['pops'])
        dat = {int(k.split('(')[0]): dat[k] for k in dat}
        dat = np.array([np.array([dat[k][subkey][()] for subkey in sorted(dat[k])]) for k in sorted(dat)])
        result.append(dat)
    return(np.array(result))

def get_2_qbit_dms(data, n_qubits, connectivity,update_rule):
    basis = ket.canonical_basis(2)
    #dimension 0 is each trial
    #dimension 1 is each time step (recall that sampling step is 5 by default)
    #dimension 2 is qubit pair
    #dimension 3 and 4 is the 2 qubit density matrix
    result = []
    
    def to_tuple(string):
        tuple_elements = string.strip('()').split(',')
        return tuple(int(elem.strip()) for elem in tuple_elements)

    for trial in data[f'{n_qubits} qubits'][f'{connectivity} connectivity']['unitary energy subspace 1']:
        seed = trial.split(' ')[-1]
        dat = dict(data[f'{n_qubits} qubits'][f'{connectivity} connectivity']['unitary energy subspace 1'][f'unitary seed {seed}'][f'ordering seed {update_rule}']['two_qubit_dms'])
        dat = {int(k.split('(')[0]): dat[k] for k in dat}
        
        dat = np.array([{to_tuple(subkey):DM.DensityMatrix(dat[k][subkey],basis) for subkey in sorted(dat[k])} for k in sorted(dat)])
        result.append(dat)
    return(np.array(result))

# %%
num=12

# %%
pops_random_c2 = get_pops(newdata1, num, "c2_2local", "random")
pops_random_c4 = get_pops(newdata1, num, "c4_2local", "random")

# %%
pops_greedy_c2 = get_pops(newdata2, num, "c2_2local", "greedy")
pops_greedy_c4 = get_pops(newdata2, num, "c4_2local", "greedy")

# %%
pops_mimic_c2 = get_pops(newdata3, num, "c2_2local", "mimic")
pops_mimic_c4 = get_pops(newdata3, num, "c4_2local", "mimic")

# %%
pops_mimic_c2_2 = get_pops(newdata3_2, num, "c2_2local", "mimic")

# %%
pops_mimic_c2 = get_pops(newdata3, num, "c2_2local", "disorder_mimic")
#pops_mimic_c4 = get_pops(newdata3, num, "c4_2local", "mimic_12_disorder")

# %%
pops_landscape_maximizes_c2 = get_pops(newdata4, num, "c2_2local", "landscape_maximizes")
pops_landscape_maximizes_c4 = get_pops(newdata4, num, "c4_2local", "landscape_maximizes")

# %%
pops_strongest_maximizes_c2 = get_pops(newdata5, num, "c2_2local", "strongest_maximizes")
pops_strongest_maximizes_c4 = get_pops(newdata5, num, "c4_2local", "strongest_maximizes")

# %%
twoQdmsrandomc2 = get_2_qbit_dms(newdata1,size,"c2_2local","random")
twoQdmsrandomc4 = get_2_qbit_dms(newdata1,size,"c4_2local","random")

# %%
twoQdmslandscape_maxc2 = get_2_qbit_dms(newdata4,size,"c2_2local","landscape_maximizes")
twoQdmslandscape_maxc4 = get_2_qbit_dms(newdata4,size,"c4_2local","landscape_maximizes")

# %%
twoQdmsmimicc2_2 = get_2_qbit_dms(newdata3_2,num,"c2_2local","mimic")

# %%
twoQdmsmimicc2 = get_2_qbit_dms(newdata3,num,"c2_2local","disorder_mimic")
#twoQdmsmimicc4 = get_2_qbit_dms(newdata3,size,"c4_2local","mimic")

# %%
twoQdmsstrongest_maxc2 = get_2_qbit_dms(newdata5,size,"c2_2local","strongest_maximizes")
twoQdmsstrongest_maxc4 = get_2_qbit_dms(newdata5,size,"c4_2local","strongest_maximizes")

# %%
import h5py
def load_orders_list(file_path: str, num_qubits, connectivity, unitary_energy_subspace, unitary_seed, order_rule_name: str):
    # Create an empty dictionary to hold orders_list
    orders_list = []

    with h5py.File(file_path, 'r') as file:
        # Construct the path to the specific group where orders_list is stored
        group_name = f"{num_qubits} qubits/{connectivity} connectivity/unitary energy subspace {unitary_energy_subspace}/unitary seed {unitary_seed}/ordering seed {order_rule_name}/previous_order"
        
        # Check if the group exists
        if group_name in file:
            group = file[group_name]
            for time_index in group:
                # Assuming the order data is stored in a dataset named 'data'
                orders_list.append(group[time_index]['data'][()])
        else:
            print(f"Group '{group_name}' not found in file.")
    
    return orders_list
outputs_c4_cs1_R1[0][12]
# Out:
# array([[ 0,  1],
#        [ 4,  6],
#        [ 8, 10],
#        [ 5,  7],
#        [ 2,  3],
#        [ 9, 11]])

# %%
#C2 
num=12
conn="c4_2local"

#CS1
outputs_c4_cs1_R1=[]
for unitary_seed in range(100):
    outputs_c4_cs1_R1.append(load_orders_list("../data/unnati_submit_12_therm_random/unnati_submit_12_therm_random.hdf5", num, conn, 1, unitary_seed, 'random')[0][9:])
outputs_c4_cs1_R1

outputs_c4_cs1_R2=[]
for unitary_seed in range(100):
    outputs_c4_cs1_R2.append(load_orders_list("../data/unnati_submit_12_therm_greedy/unnati_submit_12_therm_greedy.hdf5", num, conn, 1, unitary_seed, 'greedy')[0][9:])
outputs_c4_cs1_R2

outputs_c4_cs1_R3=[]
for unitary_seed in range(100):
    outputs_c4_cs1_R3.append(load_orders_list("../data/unnati_submit_12_therm_landmax/unnati_submit_12_therm_landmax.hdf5", num, conn, 1, unitary_seed, 'landscape_maximizes')[0][9:])
outputs_c4_cs1_R3

outputs_c4_cs1_R4=[]
for unitary_seed in range(100):
    outputs_c4_cs1_R4.append(load_orders_list("../data/unnati_submit_12_therm_strong_max/unnati_submit_12_therm_strong_max.hdf5", num, conn, 1, unitary_seed, 'strongest_maximizes')[0][9:])
outputs_c4_cs1_R4

outputs_c4_cs1_R5=[]
for unitary_seed in range(100):
    outputs_c4_cs1_R5.append(load_orders_list("../data/unnati_submit_12_therm_mimic/unnati_submit_12_therm_mimic.hdf5", num, conn, 1, unitary_seed, 'mimic')[0][9:])
outputs_c4_cs1_R5

#CS2
outputs_c4_cs2_R1=[]
for unitary_seed in range(100):
    outputs_c4_cs2_R1.append(load_orders_list("../data/unnati_submit_12_inhomo_v1_random/unnati_submit_12_inhomo_v1_random.hdf5", num, conn, 1, unitary_seed, 'random')[0][9:])
outputs_c4_cs2_R1

outputs_c4_cs2_R2=[]
for unitary_seed in range(100):
    outputs_c4_cs2_R2.append(load_orders_list("../data/unnati_submit_12_inhomo_v1_greedy/unnati_submit_12_inhomo_v1_greedy.hdf5", num, conn, 1, unitary_seed, 'greedy')[0][9:])
outputs_c4_cs2_R2

outputs_c4_cs2_R3=[]
for unitary_seed in range(100):
    outputs_c4_cs2_R3.append(load_orders_list("../data/unnati_submit_12_inhomo_v1_landmax/unnati_submit_12_inhomo_v1_landmax.hdf5", num, conn, 1, unitary_seed, 'landscape_maximizes')[0][9:])
outputs_c4_cs2_R3

outputs_c4_cs2_R4=[]
for unitary_seed in range(100):
    outputs_c4_cs2_R4.append(load_orders_list("../data/unnati_submit_12_inhomo_v1_strong_max/unnati_submit_12_inhomo_v1_strong_max.hdf5", num, conn, 1, unitary_seed, 'strongest_maximizes')[0][9:])
outputs_c4_cs2_R4

outputs_c4_cs2_R5=[]
for unitary_seed in range(100):
    outputs_c4_cs2_R5.append(load_orders_list("../data/unnati_submit_12_inhomo_v1_mimic/unnati_submit_12_inhomo_v1_mimic.hdf5", num, conn, 1, unitary_seed, 'mimic')[0][9:])
outputs_c4_cs2_R5

#CS3
outputs_c4_cs3_R1=[]
for unitary_seed in range(100):
    outputs_c4_cs3_R1.append(load_orders_list("../data/unnati_submit_12_inhomo_v2_random/unnati_submit_12_inhomo_v2_random.hdf5", num, conn, 1, unitary_seed, 'random')[0][9:])
outputs_c4_cs3_R1

outputs_c4_cs3_R2=[]
for unitary_seed in range(100):
    outputs_c4_cs3_R2.append(load_orders_list("../data/unnati_submit_12_inhomo_v2_greedy/unnati_submit_12_inhomo_v2_greedy.hdf5", num, conn, 1, unitary_seed, 'greedy')[0][9:])

outputs_c4_cs3_R5=[]
for unitary_seed in range(100):
    outputs_c4_cs3_R5.append(load_orders_list("../data/unnati_submit_12_inhomo_v2_mimic/unnati_submit_12_inhomo_v2_mimic.hdf5", num, conn, 1, unitary_seed, 'mimic')[0][9:])
outputs_c4_cs3_R5

outputs_c4_cs3_R3=[]
for unitary_seed in range(100):
    outputs_c4_cs3_R3.append(load_orders_list("../data/unnati_submit_12_inhomo_v2_landmax/unnati_submit_12_inhomo_v2_landmax.hdf5", num, conn, 1, unitary_seed, 'landscape_maximizes')[0][9:])
outputs_c4_cs3_R3

outputs_c4_cs3_R4=[]
for unitary_seed in range(100):
    outputs_c4_cs3_R4.append(load_orders_list("../data/unnati_submit_12_inhomo_v2_strongmax/unnati_submit_12_inhomo_v2_strongmax.hdf5", num, conn, 1, unitary_seed, 'strongest_maximizes')[0][9:])
outputs_c4_cs3_R4

#CSp
outputs_c4_csp_R1=[]
for unitary_seed in range(100):
    outputs_c4_csp_R1.append(load_orders_list("../data/unnati_submit_12_pure_random/unnati_submit_12_pure_random.hdf5", num, conn, 1, unitary_seed, 'random')[0][9:])
outputs_c4_csp_R1

outputs_c4_csp_R2=[]
for unitary_seed in range(100):
    outputs_c4_csp_R2.append(load_orders_list("../data/unnati_submit_12_pure_greedy/unnati_submit_12_pure_greedy.hdf5", num, conn, 1, unitary_seed, 'greedy')[0][9:])
outputs_c4_csp_R2

outputs_c4_csp_R3=[]
for unitary_seed in range(100):
    outputs_c4_csp_R3.append(load_orders_list("../data/unnati_submit_12_pure_landmax/unnati_submit_12_pure_landmax.hdf5", num, conn, 1, unitary_seed, 'landscape_maximizes')[0][9:])
outputs_c4_csp_R3

outputs_c4_csp_R4=[]
for unitary_seed in range(100):
    outputs_c4_csp_R4.append(load_orders_list("../data/unnati_submit_12_pure_strongmax/unnati_submit_12_pure_strongmax.hdf5", num, conn, 1, unitary_seed, 'strongest_maximizes')[0][9:])
outputs_c4_csp_R4

outputs_c4_csp_R5=[]
for unitary_seed in range(100):
    outputs_c4_csp_R5.append(load_orders_list("../data/unnati_submit_12_pure_mimic/unnati_submit_12_pure_mimic.hdf5", num, conn, 1, unitary_seed, 'mimic')[0][9:])
outputs_c4_csp_R5

configs=[np.array([[10, 11],
                    [ 6,  7],
                    [ 4,  5],
                    [ 0,  2],
                    [ 8,  9],
                    [ 1,  3]]),
            np.array([[ 9, 10],
                    [ 1,  2],
                    [ 3,  4],
                    [ 0, 11],
                    [ 5,  6],
                    [ 7,  8]]),
            np.array([[ 1,  2],
                    [ 3,  4],
                    [ 8, 10],
                    [ 7,  9],
                    [ 5,  6],
                    [ 0, 11]]),
            np.array([[ 8, 10],
                    [ 6,  7],
                    [ 4,  5],
                    [ 0,  2],
                    [ 9, 11],
                    [ 1,  3]]),
            np.array([[ 9, 10],
                    [ 2,  4],
                    [ 6,  8],
                    [ 5,  7],
                    [ 1,  3],
                    [ 0, 11]]),
            np.array([[ 0,  1],
                    [ 2,  4],
                    [10, 11],
                    [ 6,  8],
                    [ 7,  9],
                    [ 3,  5]]),
            np.array([[ 0,  1],
                    [ 4,  6],
                    [ 8, 10],
                    [ 5,  7],
                    [ 2,  3],
                    [ 9, 11]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 5,  6],
                    [ 9, 11],
                    [ 1,  3],
                    [ 7,  8]]),
            np.array([[ 0, 10],
                    [ 1, 11],
                    [ 2,  3],
                    [ 6,  7],
                    [ 4,  5],
                    [ 8,  9]]),
            np.array([[ 9, 10],
                    [ 1,  2],
                    [ 3,  4],
                    [ 6,  8],
                    [ 5,  7],
                    [ 0, 11]]),
            np.array([[ 1,  2],
                    [ 0, 10],
                    [ 4,  6],
                    [ 9, 11],
                    [ 3,  5],
                    [ 7,  8]]),
            np.array([[ 0,  1],
                    [ 2,  4],
                    [ 8, 10],
                    [ 6,  7],
                    [ 9, 11],
                    [ 3,  5]]),
            np.array([[10, 11],
                    [ 6,  8],
                    [ 7,  9],
                    [ 4,  5],
                    [ 0,  2],
                    [ 1,  3]]),
            np.array([[ 0,  1],
                    [10, 11],
                    [ 4,  6],
                    [ 5,  7],
                    [ 2,  3],
                    [ 8,  9]]),
            np.array([[ 9, 10],
                    [ 1, 11],
                    [ 4,  6],
                    [ 0,  2],
                    [ 3,  5],
                    [ 7,  8]]),
            np.array([[ 1, 11],
                    [ 4,  6],
                    [ 8, 10],
                    [ 7,  9],
                    [ 0,  2],
                    [ 3,  5]]),
            np.array([[ 4,  6],
                    [ 8, 10],
                    [ 5,  7],
                    [ 0,  2],
                    [ 9, 11],
                    [ 1,  3]]),
            np.array([[ 0, 10],
                    [ 1, 11],
                    [ 6,  8],
                    [ 2,  3],
                    [ 7,  9],
                    [ 4,  5]]),
            np.array([[ 0, 10],
                    [ 1, 11],
                    [ 4,  6],
                    [ 5,  7],
                    [ 2,  3],
                    [ 8,  9]]),
            np.array([[ 0,  1],
                    [10, 11],
                    [ 2,  3],
                    [ 6,  7],
                    [ 4,  5],
                    [ 8,  9]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 1, 11],
                    [ 6,  7],
                    [ 8,  9],
                    [ 3,  5]]),
            np.array([[ 1,  2],
                    [ 0, 10],
                    [ 3,  4],
                    [ 6,  8],
                    [ 5,  7],
                    [ 9, 11]]),
            np.array([[ 0,  1],
                    [10, 11],
                    [ 6,  8],
                    [ 2,  3],
                    [ 7,  9],
                    [ 4,  5]]),
            np.array([[10, 11],
                    [ 4,  6],
                    [ 5,  7],
                    [ 0,  2],
                    [ 8,  9],
                    [ 1,  3]]),
            np.array([[ 9, 10],
                    [ 3,  4],
                    [ 1, 11],
                    [ 6,  8],
                    [ 5,  7],
                    [ 0,  2]]),
            np.array([[ 9, 10],
                    [ 2,  4],
                    [ 0, 11],
                    [ 5,  6],
                    [ 1,  3],
                    [ 7,  8]]),
            np.array([[ 2,  4],
                    [ 8, 10],
                    [ 7,  9],
                    [ 5,  6],
                    [ 1,  3],
                    [ 0, 11]]),
            np.array([[ 3,  4],
                    [ 1, 11],
                    [ 8, 10],
                    [ 7,  9],
                    [ 0,  2],
                    [ 5,  6]]),
            np.array([[ 0,  1],
                    [ 2,  4],
                    [10, 11],
                    [ 6,  7],
                    [ 8,  9],
                    [ 3,  5]]),
            np.array([[ 9, 10],
                    [ 3,  4],
                    [ 1, 11],
                    [ 0,  2],
                    [ 5,  6],
                    [ 7,  8]]),
            np.array([[ 9, 10],
                    [ 1,  2],
                    [ 4,  6],
                    [ 0, 11],
                    [ 3,  5],
                    [ 7,  8]]),
            np.array([[ 1,  2],
                    [ 4,  6],
                    [ 8, 10],
                    [ 0, 11],
                    [ 7,  9],
                    [ 3,  5]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 6,  8],
                    [ 5,  7],
                    [ 9, 11],
                    [ 1,  3]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 1, 11],
                    [ 6,  8],
                    [ 7,  9],
                    [ 3,  5]]),
            np.array([[ 1,  2],
                    [ 0, 10],
                    [ 3,  4],
                    [ 5,  6],
                    [ 9, 11],
                    [ 7,  8]]),
            np.array([[ 0,  1],
                    [ 8, 10],
                    [ 2,  3],
                    [ 6,  7],
                    [ 4,  5],
                    [ 9, 11]])]

def convert_config_to_binary(outputs,configs):
    configs=[np.array([[10, 11],
                    [ 6,  7],
                    [ 4,  5],
                    [ 0,  2],
                    [ 8,  9],
                    [ 1,  3]]),
            np.array([[ 9, 10],
                    [ 1,  2],
                    [ 3,  4],
                    [ 0, 11],
                    [ 5,  6],
                    [ 7,  8]]),
            np.array([[ 1,  2],
                    [ 3,  4],
                    [ 8, 10],
                    [ 7,  9],
                    [ 5,  6],
                    [ 0, 11]]),
            np.array([[ 8, 10],
                    [ 6,  7],
                    [ 4,  5],
                    [ 0,  2],
                    [ 9, 11],
                    [ 1,  3]]),
            np.array([[ 9, 10],
                    [ 2,  4],
                    [ 6,  8],
                    [ 5,  7],
                    [ 1,  3],
                    [ 0, 11]]),
            np.array([[ 0,  1],
                    [ 2,  4],
                    [10, 11],
                    [ 6,  8],
                    [ 7,  9],
                    [ 3,  5]]),
            np.array([[ 0,  1],
                    [ 4,  6],
                    [ 8, 10],
                    [ 5,  7],
                    [ 2,  3],
                    [ 9, 11]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 5,  6],
                    [ 9, 11],
                    [ 1,  3],
                    [ 7,  8]]),
            np.array([[ 0, 10],
                    [ 1, 11],
                    [ 2,  3],
                    [ 6,  7],
                    [ 4,  5],
                    [ 8,  9]]),
            np.array([[ 9, 10],
                    [ 1,  2],
                    [ 3,  4],
                    [ 6,  8],
                    [ 5,  7],
                    [ 0, 11]]),
            np.array([[ 1,  2],
                    [ 0, 10],
                    [ 4,  6],
                    [ 9, 11],
                    [ 3,  5],
                    [ 7,  8]]),
            np.array([[ 0,  1],
                    [ 2,  4],
                    [ 8, 10],
                    [ 6,  7],
                    [ 9, 11],
                    [ 3,  5]]),
            np.array([[10, 11],
                    [ 6,  8],
                    [ 7,  9],
                    [ 4,  5],
                    [ 0,  2],
                    [ 1,  3]]),
            np.array([[ 0,  1],
                    [10, 11],
                    [ 4,  6],
                    [ 5,  7],
                    [ 2,  3],
                    [ 8,  9]]),
            np.array([[ 9, 10],
                    [ 1, 11],
                    [ 4,  6],
                    [ 0,  2],
                    [ 3,  5],
                    [ 7,  8]]),
            np.array([[ 1, 11],
                    [ 4,  6],
                    [ 8, 10],
                    [ 7,  9],
                    [ 0,  2],
                    [ 3,  5]]),
            np.array([[ 4,  6],
                    [ 8, 10],
                    [ 5,  7],
                    [ 0,  2],
                    [ 9, 11],
                    [ 1,  3]]),
            np.array([[ 0, 10],
                    [ 1, 11],
                    [ 6,  8],
                    [ 2,  3],
                    [ 7,  9],
                    [ 4,  5]]),
            np.array([[ 0, 10],
                    [ 1, 11],
                    [ 4,  6],
                    [ 5,  7],
                    [ 2,  3],
                    [ 8,  9]]),
            np.array([[ 0,  1],
                    [10, 11],
                    [ 2,  3],
                    [ 6,  7],
                    [ 4,  5],
                    [ 8,  9]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 1, 11],
                    [ 6,  7],
                    [ 8,  9],
                    [ 3,  5]]),
            np.array([[ 1,  2],
                    [ 0, 10],
                    [ 3,  4],
                    [ 6,  8],
                    [ 5,  7],
                    [ 9, 11]]),
            np.array([[ 0,  1],
                    [10, 11],
                    [ 6,  8],
                    [ 2,  3],
                    [ 7,  9],
                    [ 4,  5]]),
            np.array([[10, 11],
                    [ 4,  6],
                    [ 5,  7],
                    [ 0,  2],
                    [ 8,  9],
                    [ 1,  3]]),
            np.array([[ 9, 10],
                    [ 3,  4],
                    [ 1, 11],
                    [ 6,  8],
                    [ 5,  7],
                    [ 0,  2]]),
            np.array([[ 9, 10],
                    [ 2,  4],
                    [ 0, 11],
                    [ 5,  6],
                    [ 1,  3],
                    [ 7,  8]]),
            np.array([[ 2,  4],
                    [ 8, 10],
                    [ 7,  9],
                    [ 5,  6],
                    [ 1,  3],
                    [ 0, 11]]),
            np.array([[ 3,  4],
                    [ 1, 11],
                    [ 8, 10],
                    [ 7,  9],
                    [ 0,  2],
                    [ 5,  6]]),
            np.array([[ 0,  1],
                    [ 2,  4],
                    [10, 11],
                    [ 6,  7],
                    [ 8,  9],
                    [ 3,  5]]),
            np.array([[ 9, 10],
                    [ 3,  4],
                    [ 1, 11],
                    [ 0,  2],
                    [ 5,  6],
                    [ 7,  8]]),
            np.array([[ 9, 10],
                    [ 1,  2],
                    [ 4,  6],
                    [ 0, 11],
                    [ 3,  5],
                    [ 7,  8]]),
            np.array([[ 1,  2],
                    [ 4,  6],
                    [ 8, 10],
                    [ 0, 11],
                    [ 7,  9],
                    [ 3,  5]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 6,  8],
                    [ 5,  7],
                    [ 9, 11],
                    [ 1,  3]]),
            np.array([[ 2,  4],
                    [ 0, 10],
                    [ 1, 11],
                    [ 6,  8],
                    [ 7,  9],
                    [ 3,  5]]),
            np.array([[ 1,  2],
                    [ 0, 10],
                    [ 3,  4],
                    [ 5,  6],
                    [ 9, 11],
                    [ 7,  8]]),
            np.array([[ 0,  1],
                    [ 8, 10],
                    [ 2,  3],
                    [ 6,  7],
                    [ 4,  5],
                    [ 9, 11]])]
    config_list_all_trials = []
    for configs_per_trial in outputs:
        configs_per_trial = configs_per_trial[0:500]
        config_list = []
        for i, config_from_trial in enumerate(configs_per_trial):
            for j, reference_config in enumerate(configs):
                if np.array_equal(config_from_trial, reference_config):
                    config_list.append(j)
                    break
        config_list_all_trials.append(config_list)
    return config_list_all_trials


#CS1
config_list_CS1_R1=convert_config_to_binary(outputs_c4_cs1_R1,configs)
config_list_CS1_R2=convert_config_to_binary(outputs_c4_cs1_R2,configs)
config_list_CS1_R3=convert_config_to_binary(outputs_c4_cs1_R3,configs)
config_list_CS1_R4=convert_config_to_binary(outputs_c4_cs1_R4,configs)
config_list_CS1_R5=convert_config_to_binary(outputs_c4_cs1_R5,configs)

#CS2
config_list_CS2_R1=convert_config_to_binary(outputs_c4_cs2_R1,configs)
config_list_CS2_R2=convert_config_to_binary(outputs_c4_cs2_R2,configs)
config_list_CS2_R3=convert_config_to_binary(outputs_c4_cs2_R3,configs)
config_list_CS2_R4=convert_config_to_binary(outputs_c4_cs2_R4,configs)
config_list_CS2_R5=convert_config_to_binary(outputs_c4_cs2_R5,configs)

#CS3
config_list_CS3_R1=convert_config_to_binary(outputs_c4_cs3_R1,configs)
config_list_CS3_R2=convert_config_to_binary(outputs_c4_cs3_R2,configs)
config_list_CS3_R3=convert_config_to_binary(outputs_c4_cs3_R3,configs)
config_list_CS3_R4=convert_config_to_binary(outputs_c4_cs3_R4,configs)
config_list_CS3_R5=convert_config_to_binary(outputs_c4_cs3_R5,configs)

#CSP
config_list_CSP_R1=convert_config_to_binary(outputs_c4_csp_R1,configs)
config_list_CSP_R2=convert_config_to_binary(outputs_c4_csp_R2,configs)
config_list_CSP_R3=convert_config_to_binary(outputs_c4_csp_R3,configs)
config_list_CSP_R4=convert_config_to_binary(outputs_c4_csp_R4,configs)
config_list_CSP_R5=convert_config_to_binary(outputs_c4_csp_R5,configs)
len(config_list_CS1_R1)
#10,16,26
# Out:
# 100

# %%
import csv
import pandas as pd

# Create column headers from t10 to t160
headers = [f't{i+11}' for i in range(489)]

# Writing to a CSV file
with open('config_list_CSP_R5_steps_10_500_C4.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write the headers first
    writer.writerow(headers)
    # Then write the data rows
    for row in config_list_CSP_R5:
        writer.writerow(row)

# Read CSV into a pandas DataFrame
df = pd.read_csv('config_list_CSP_R5_steps_10_500_C4.csv')

# Convert to list of lists if needed
binary_data = df.values.tolist()

# Or work directly with the DataFrame
print(df)
# Out:
#     t11  t12  t13  t14  t15  t16  t17  t18  t19  t20  ...  t490  t491  t492  \
# 0    35    3   21   24   29   26   26    8   21   27  ...    17    32    28
# 1    24    3    5   17    8   17   17    0   14   20  ...    25    29    15
# 2     6   15    0    2    9   24    1    9    1    4  ...    13    33    19
# 3    16   16   31   20   18   15    5   28   20    6  ...    22    22    22
# 4    22   33   33   33   33   17    4    5   18   11  ...     8    22     6
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 95   27    7   15   31   13   15   20   16    4    2  ...    35    31    23
# 96   24    7   32   24   13    5   10   10   11   11  ...    28    29     2
# 97    0   35    6   15   34    5   30   11   10   16  ...    20    11     1
# 98    7   16   24    5    0   32   28   32    0   22  ...     3     8    32
# 99   34   28   23   25   32   29   26   25   11    1  ...    31     7    11
#
#     t493  t494  t495  t496  t497  t498  t499
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap
import seaborn as sns

# Generate sample data - replace this with your actual data
# Creating 100 arrays of length 500 with random values between 0-35
data = config_list_CS1_R5

# Create a discrete colormap with 36 distinct colors (for values 0-35)
# Using a combination of colorblind-friendly palettes
def generate_distinct_colors(n):
    """Generate n visually distinct colors"""
    # Start with some base palettes
    base_colors = []
    
    # Add colors from tab20 (20 colors)
    base_colors.extend(plt.cm.tab20.colors)
    
    # Add colors from tab20b (20 colors)
    base_colors.extend(plt.cm.tab20b.colors)
    
    # Add colors from tab20c (20 colors)
    base_colors.extend(plt.cm.tab20c.colors)
    
    # If we need more colors, add some from other palettes
    if n > len(base_colors):
        # Add colors from Set3 (12 colors)
        base_colors.extend(plt.cm.Set3.colors)
    
    # Take the first n colors
    colors = base_colors[:n]
    
    # If we still need more colors, interpolate between existing ones
    if n > len(colors):
        # Create a colormap from existing colors and sample more colors
        existing_cmap = ListedColormap(colors)
        additional_colors = [existing_cmap(i) for i in np.linspace(0, 1, n - len(colors))]
        colors.extend(additional_colors)
    
    return colors[:n]

# Generate 36 distinct colors for values 0-35
colors = generate_distinct_colors(36)
cmap = ListedColormap(colors)

# Setting up the figure
plt.figure(figsize=(14, 10))

# Plot the heatmap
ax = sns.heatmap(data, cmap=cmap, cbar=True, 
                 cbar_kws={'ticks': np.arange(0, 36, 5),
                           'label': 'Value (0-35)'})

# Configure the plot
plt.title('Discrete Heatmap of 100 Arrays (Values 0-35)', fontsize=16)
plt.xlabel('Array Position (0-499)', fontsize=12)
plt.ylabel('Array Number (0-99)', fontsize=12)

# Set x-ticks at reasonable intervals
plt.xticks(np.arange(0, 501, 50))

# Show the plot
plt.tight_layout()
plt.show()

# To interpret specific patterns in this visualization:
# - Each row represents one of your 100 arrays
# - Each column position (0-499) shows the value at that position
# - The color represents the value (0-35) according to the colorbar

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = config_list_CS1_R4

# Flatten the 2D array to analyze all values together
flat_data = np.array(data).flatten()

# Setting up the figure with multiple plots
fig, axs = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Distribution Analysis of Values (0-35)', fontsize=20)

# 1. Histogram in the top-left
axs[0, 0].hist(flat_data, bins=36, color='royalblue', edgecolor='black', alpha=0.7)
axs[0, 0].set_title('Histogram of Values', fontsize=16)
axs[0, 0].set_xlabel('Value (0-35)', fontsize=12)
axs[0, 0].set_ylabel('Frequency', fontsize=12)
axs[0, 0].set_xticks(np.arange(0, 36, 2))
axs[0, 0].grid(alpha=0.3)

# 2. Bar plot in the top-right showing counts for each value
unique_values, counts = np.unique(flat_data, return_counts=True)
axs[0, 1].bar(unique_values, counts, color='green', alpha=0.7, edgecolor='black')
axs[0, 1].set_title('Count of Each Value', fontsize=16)
axs[0, 1].set_xlabel('Value (0-35)', fontsize=12)
axs[0, 1].set_ylabel('Count', fontsize=12)
axs[0, 1].set_xticks(np.arange(0, 36, 2))
axs[0, 1].grid(axis='y', alpha=0.3)

# 3. Heatmap showing distribution by array in the bottom-left
# Calculate percentage of each value in each array
array_distributions = np.zeros((100, 36))
for i in range(100):
    unique, counts = np.unique(data[i], return_counts=True)
    for u, c in zip(unique, counts):
        array_distributions[i, u] = c / 500 * 100  # Convert to percentage

# Plot heatmap of distributions
sns.heatmap(array_distributions, cmap='viridis', ax=axs[1, 0])
axs[1, 0].set_title('Distribution (%) of Values by Array', fontsize=16)
axs[1, 0].set_xlabel('Value (0-35)', fontsize=12)
axs[1, 0].set_ylabel('Array Number (0-99)', fontsize=12)
axs[1, 0].set_xticks(np.arange(0, 36, 5))

# 4. Box plot showing distribution of values in the bottom-right
# For each position in the array, what's the distribution of values?
positions_sample = np.arange(0, 500, 25)  # Sample every 25th position to avoid overcrowding
boxplot_data = [data[:, pos] for pos in positions_sample]
axs[1, 1].boxplot(boxplot_data, patch_artist=True)
axs[1, 1].set_title('Distribution at Sample Positions', fontsize=16)
axs[1, 1].set_xlabel('Array Position (every 25th)', fontsize=12)
axs[1, 1].set_ylabel('Value (0-35)', fontsize=12)
axs[1, 1].set_xticklabels(positions_sample)
axs[1, 1].grid(axis='y', alpha=0.3)

# Statistical summary
print("Statistical Summary:")
print(f"Mean value: {np.mean(flat_data):.2f}")
print(f"Median value: {np.median(flat_data):.2f}")
print(f"Most common value: {np.bincount(flat_data).argmax()}")
print(f"Least common value: {np.bincount(flat_data).argmin()}")
print(f"Standard deviation: {np.std(flat_data):.2f}")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout with space for suptitle
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 49
#      46 # 4. Box plot showing distribution of values in the bottom-right
#      47 # For each position in the array, what's the distribution of values?
#      48 positions_sample = np.arange(0, 500, 25)  # Sample every 25th position to avoid overcrowding
# ---> 49 boxplot_data = [data[:, pos] for pos in positions_sample]
#      50 axs[1, 1].boxplot(boxplot_data, patch_artist=True)
#      51 axs[1, 1].set_title('Distribution at Sample Positions', fontsize=16)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
import seaborn as sns
data = config_list_CS1_R5

# Function 1: Recurrence Plot
def create_recurrence_plot(sequence, threshold=0):
    """
    Create a recurrence plot for a single sequence.
    
    Parameters:
    sequence : array-like
        The input sequence to analyze
    threshold : int or float
        Distance threshold for considering two points recurrent
        
    Returns:
    recurrence_matrix : 2D numpy array
        The recurrence plot as a binary matrix
    """
    N = len(sequence)
    recurrence_matrix = np.zeros((N, N))
    
    for i in range(N):
        for j in range(N):
            # Two points are recurrent if they have the same value or difference <= threshold
            if abs(sequence[i] - sequence[j]) <= threshold:
                recurrence_matrix[i, j] = 1
                
    return recurrence_matrix

# Function 2: Sequential Pattern Mining (simplified)
def find_frequent_patterns(sequence, min_length=2, max_length=5, min_support=3):
    """
    Find frequent subsequences in a sequence.
    
    Parameters:
    sequence : array-like
        The input sequence to analyze
    min_length : int
        Minimum pattern length to consider
    max_length : int
        Maximum pattern length to consider
    min_support : int
        Minimum number of occurrences required
        
    Returns:
    patterns : dict
        Dictionary of patterns and their counts
    """
    patterns = defaultdict(int)
    N = len(sequence)
    
    # Generate all subsequences of specified lengths
    for length in range(min_length, min(max_length + 1, N)):
        for i in range(N - length + 1):
            # Convert subsequence to tuple for hashability
            pattern = tuple(sequence[i:i+length])
            patterns[pattern] += 1
    
    # Filter by minimum support
    frequent_patterns = {k: v for k, v in patterns.items() if v >= min_support}
    return frequent_patterns

# Function 3: Markov Model
def build_markov_model(sequence, order=1):
    """
    Build a Markov model of specified order.
    
    Parameters:
    sequence : array-like
        The input sequence to analyze
    order : int
        Order of the Markov model (1 = depends on previous state only)
        
    Returns:
    transitions : dict
        Nested dictionary of transition counts
    transition_probs : dict
        Nested dictionary of transition probabilities
    """
    transitions = defaultdict(Counter)
    
    # Count transitions
    for i in range(len(sequence) - order):
        # Current state (can be a single value or tuple for higher orders)
        if order == 1:
            current = sequence[i]
        else:
            current = tuple(sequence[i:i+order])
            
        # Next state
        next_state = sequence[i+order]
        
        # Count this transition
        transitions[current][next_state] += 1
    
    # Convert counts to probabilities
    transition_probs = {}
    for current, next_counts in transitions.items():
        total = sum(next_counts.values())
        transition_probs[current] = {next_state: count/total 
                                    for next_state, count in next_counts.items()}
    
    return transitions, transition_probs

# Example usage with visualization
def analyze_temporal_patterns(data, array_idx=0, plot=True):
    """
    Analyze temporal patterns in a single array using all three methods.
    
    Parameters:
    data : 2D array
        The complete dataset
    array_idx : int
        Index of the array to analyze
    plot : bool
        Whether to create visualizations
    """
    sequence = data[array_idx]
    results = {}
    
    # 1. Create recurrence plot
    recurrence_matrix = create_recurrence_plot(sequence, threshold=0)
    results['recurrence_plot'] = recurrence_matrix
    
    # 2. Find frequent patterns
    frequent_patterns = find_frequent_patterns(sequence, min_support=5)
    # Sort by frequency (descending)
    sorted_patterns = sorted(frequent_patterns.items(), key=lambda x: x[1], reverse=True)
    results['frequent_patterns'] = sorted_patterns
    
    # 3. Build Markov model
    transitions, transition_probs = build_markov_model(sequence, order=1)
    results['transitions'] = transitions
    results['transition_probs'] = transition_probs
    
    # Create visualizations if requested
    if plot:
        plt.figure(figsize=(18, 12))
        
        # 1. Plot recurrence plot
        plt.subplot(2, 2, 1)
        plt.imshow(recurrence_matrix, cmap='binary', origin='lower')
        plt.title(f'Recurrence Plot (Array {array_idx})', fontsize=14)
        plt.xlabel('Position in Sequence')
        plt.ylabel('Position in Sequence')
        plt.colorbar(label='Recurrence')
        
        # 2. Plot top frequent patterns
        plt.subplot(2, 2, 2)
        top_n = min(10, len(sorted_patterns))
        if top_n > 0:
            patterns = [' → '.join(map(str, pattern)) for pattern, _ in sorted_patterns[:top_n]]
            counts = [count for _, count in sorted_patterns[:top_n]]
            
            y_pos = np.arange(len(patterns))
            plt.barh(y_pos, counts)
            plt.yticks(y_pos, patterns)
            plt.title(f'Top {top_n} Frequent Patterns', fontsize=14)
            plt.xlabel('Frequency')
        else:
            plt.text(0.5, 0.5, 'No patterns found with specified support', 
                     ha='center', va='center', fontsize=12)
        
        # 3. Plot Markov transition matrix
        plt.subplot(2, 2, 3)
        # Create transition matrix for visualization
        unique_states = np.unique(sequence)
        n_states = len(unique_states)
        markov_matrix = np.zeros((n_states, n_states))
        
        # Map states to indices
        state_to_idx = {state: idx for idx, state in enumerate(unique_states)}
        
        # Fill the matrix
        for current, next_probs in transition_probs.items():
            for next_state, prob in next_probs.items():
                markov_matrix[state_to_idx[current], state_to_idx[next_state]] = prob
        
        # Plot as heatmap
        sns.heatmap(markov_matrix, cmap='viridis')
        plt.title('Markov Transition Probabilities', fontsize=14)
        plt.xlabel('Next State')
        plt.ylabel('Current State')
        
        # 4. Additional insights
        plt.subplot(2, 2, 4)
        plt.axis('off')
        
        # Recurrence plot insights
        diagonal_lines = np.sum(np.diagonal(recurrence_matrix))
        recurrence_rate = np.sum(recurrence_matrix) / (len(sequence) ** 2)
        
        # Markov insights
        if len(transition_probs) > 0:
            avg_transitions = np.mean([len(next_states) for next_states in transition_probs.values()])
            most_common_state = Counter(sequence).most_common(1)[0][0]
            next_after_common = sorted(transition_probs.get(most_common_state, {}).items(), 
                                      key=lambda x: x[1], reverse=True)
        else:
            avg_transitions = 0
            most_common_state = 'N/A'
            next_after_common = []
        
        # Display insights
        insights = [
            f"Recurrence rate: {recurrence_rate:.4f}",
            f"Diagonal line strength: {diagonal_lines}",
            f"Average outgoing transitions per state: {avg_transitions:.2f}",
            f"Most common state: {most_common_state}",
            "Most likely transitions after most common state:"
        ]
        
        for i, line in enumerate(insights):
            plt.text(0.05, 0.95 - i*0.07, line, fontsize=12, va='top')
        
        y_offset = len(insights) * 0.07
        for i, (next_state, prob) in enumerate(next_after_common[:5]):
            plt.text(0.1, 0.95 - y_offset - i*0.05, 
                     f"{most_common_state} → {next_state}: {prob:.3f}", fontsize=10, va='top')
        
        plt.tight_layout()
        plt.show()
    
    return results

# Analyze a single array (change index as needed)
results = analyze_temporal_patterns(data, array_idx=0, plot=True)

# To analyze multiple arrays, use:
# for idx in range(5):  # Analyze first 5 arrays
#     analyze_temporal_patterns(data, array_idx=idx, plot=True)

# Print additional information about the results
print("\nTop 5 Frequent Patterns:")
for pattern, count in results['frequent_patterns'][:5]:
    print(f"Pattern {pattern}: occurs {count} times")

print("\nSample of Markov Transitions:")
# Show transitions from first 3 states
for i, (state, next_states) in enumerate(results['transition_probs'].items()):
    if i >= 5:
        break
    print(f"From state {state}:")
    for next_state, prob in sorted(next_states.items(), key=lambda x: x[1], reverse=True)[:3]:
        print(f"  → {next_state}: {prob:.3f}")
# Out:
# Top 5 Frequent Patterns:
# Pattern (18, 18): occurs 10 times
# Pattern (25, 25): occurs 9 times
# Pattern (8, 8): occurs 9 times
# Pattern (17, 17): occurs 7 times
# Pattern (15, 15): occurs 7 times
#
# Sample of Markov Transitions:
# From state 22:
#   → 17: 0.167
#   → 35: 0.167
#   → 6: 0.167
# From state 17:
#   → 17: 0.304
#   → 13: 0.130
#   → 8: 0.087
# From state 8:
#   → 8: 0.346
#   → 18: 0.154
#   → 6: 0.115
# From state 18:
#   → 18: 0.345
#   → 8: 0.103
#   → 23: 0.069
# From state 23:
#   → 13: 0.118
#   → 21: 0.118
#   → 0: 0.118

# %%
#code to generate how many time a particular neighbourhood shows up
from collections import defaultdict
occurrences = defaultdict(int)

# Loop through thenp.array and count each neighbourhood's occurrence
def dictionary_of_neighbourhoods(array_of_arrays_of_arrays):
    fornp.array innp.array_of_arrays_of_arrays:
        for subarray innp.array:
        # Convert each list (subarray) to a tuple (to make it hashable)
            tuple_subarray = tuple(map(tuple, subarray))  # Convert list of lists to tuple of tuples
            occurrences[tuple_subarray] += 1

# Print the occurrences of each neighbourhood
    dictionary = []
    for key, value in occurrences.items():
        dictionary.append([key, value])
    return dictionary

# Function to get all distinct neighbourhoods
def get_distinct_neighbourhoods(data):
    distinct_neighbourhoods = []
    for neighbourhood in data:
        # Check if the neighbourhood is already in the list of distinct neighbourhoods
        if not any(np.array_equal(neighbourhood, existing_neighbourhood) for existing_neighbourhood in distinct_neighbourhoods):
            distinct_neighbourhoods.append(neighbourhood)
    return distinct_neighbourhoods


# Function to track when each neighbourhood appears
def find_neighbourhood_appearances(data, distinct_neighbourhoods):
    time_steps = []
    for t, neighbourhood in enumerate(data):
        for i, distinct_neighbourhood in enumerate(distinct_neighbourhoods):
            if np.array_equal(neighbourhood, distinct_neighbourhood):
                time_steps.append((t + 1, f'{chr(97 + i)}'))  # Assign a label a, b, c, ...
    return time_steps
get_distinct_neighbourhoods(outputs_c4_cs1_R1[0])
# Out:
# [array([[11,  0],
#         [ 3,  8],
#         [10,  5],
#         [ 9,  6],
#         [ 2,  4],
#         [ 7,  1]]),
#  array([[ 8, 10],
#         [ 6,  7],
#         [ 4,  5],
#         [ 0,  2],
#         [ 9, 11],
#         [ 1,  3]]),
#  array([[ 0, 10],
#         [ 1, 11],
#         [ 6,  8],
#         [ 2,  3],
#         [ 7,  9],
#         [ 4,  5]]),
#  array([[ 0,  1],
#         [10, 11],
#         [ 6,  8],
#         [ 2,  3],
#         [ 7,  9],
#         [ 4,  5]]),
#  array([[ 1,  2],
#         [ 0, 10],
#         [ 4,  6],
#         [ 9, 11],
#         [ 3,  5],
#         [ 7,  8]]),
#  array([[ 2,  4],
#         [ 0, 10],
#         [ 1, 11],
#         [ 6,  8],
#         [ 7,  9],
#         [ 3,  5]]),
#  array([[ 1,  2],
#         [ 0, 10],
#         [ 3,  4],
#         [ 6,  8],
#         [ 5,  7],
#         [ 9, 11]]),
#  array([[ 2,  4],
#         [ 8, 10],
#         [ 7,  9],
#         [ 5,  6],
#         [ 1,  3],
#         [ 0, 11]]),
#  array([[ 0,  1],
# ...

# %%
data=outputs_R2_c2[8][0:499]
# Get the distinct neighbourhoods
distinct_neighbourhoods = get_distinct_neighbourhoods(data)

# Track when each neighbourhood appears
time_steps = find_neighbourhood_appearances(data, distinct_neighbourhoods)

# Separate out the time and labels for plotting
times = [t for t, label in time_steps]
labels = [label for t, label in time_steps]

# Plotting
plt.figure(figsize=(18, 6))
plt.plot(times, labels, marker='o', linestyle='-', markersize=8)

# Customize the plot
plt.xticks(times)  # Show time steps on x-axis
plt.yticks(list(set(labels)))  # Show neighbourhood labels (a, b, c, ...) on y-axis
plt.xlabel('Time')
plt.ylabel('Neighbourhood')
plt.title('Neighbourhoods over Time')
plt.grid(True)

# Show the plot
plt.show()

# Print the distinct neighbourhoods
print("Distinct Neighbourhoods:")
for i, neighbourhood in enumerate(distinct_neighbourhoods):
    print(f"{chr(97 + i)}: {neighbourhood}")
# Out:
# Distinct Neighbourhoods:
# a: [[ 3 10]
#  [11  7]
#  [ 4  2]
#  [ 0  6]
#  [ 9  5]
#  [ 1  8]]
# b: [[ 0  1]
#  [10 11]
#  [ 2  3]
#  [ 6  7]
#  [ 4  5]
#  [ 8  9]]
# c: [[ 9 10]
#  [ 1  2]
#  [ 3  4]
#  [ 0 11]
#  [ 5  6]
#  [ 7  8]]

# %%
choices_at_t = outputs_R3_c2[:, 1]
choices_at_t
get_distinct_neighbourhoods(np.array(outputs_R3_c2[1]))[0]
calculate_choice_frequencies(data)
# Out:
# (array([0.51416667, 0.51416667, 0.46833333, 0.41333333, 0.5325    ,
#         0.51416667, 0.49583333, 0.46833333, 0.5325    , 0.55083333,
#         0.49583333, 0.55083333, 0.51416667, 0.5875    , 0.54166667,
#         0.55083333, 0.49583333, 0.56      , 0.54166667, 0.49583333,
#         0.52333333, 0.51416667, 0.5875    , 0.57833333, 0.49583333,
#         0.505     , 0.49583333, 0.49583333, 0.5325    , 0.38583333,
#         0.52333333, 0.49583333, 0.505     , 0.45916667, 0.55083333,
#         0.5875    , 0.52333333, 0.505     , 0.52333333, 0.505     ,
#         0.60583333, 0.46833333, 0.52333333, 0.63333333, 0.45      ,
#         0.55083333, 0.59666667, 0.46833333, 0.4775    , 0.51416667,
#         0.48666667, 0.44083333, 0.55083333, 0.44083333, 0.54166667,
#         0.45      , 0.4775    , 0.56      , 0.54166667, 0.5325    ,
#         0.46833333, 0.48666667, 0.54166667, 0.51416667, 0.49583333,
#         0.4775    , 0.48666667, 0.51416667, 0.45      , 0.45      ,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate the proportion of two choices (Choice 1 and Choice 2) at each time step
def calculate_choice_frequencies(data):
    # Number of trials and time steps
    num_trials = 100
    num_time_steps =489
    # Initializenp.arrays to store the proportions of Choice 1 and Choice 2
    proportion_choice_1 = np.zeros(num_time_steps)
    proportion_choice_2 = np.zeros(num_time_steps)
    distinct_neighbourhoods = get_distinct_neighbourhoods(data[1])

    std_choice_1 = np.zeros(num_time_steps)
    std_choice_2 = np.zeros(num_time_steps)

    # For each time step, calculate the proportion of Choice 1 and Choice 2
    for t in range(num_time_steps):
        choices_at_t = data[:, t]  # Get all choices at time step t (for all trials)
        proportion_choice_1[t] = np.mean(choices_at_t == distinct_neighbourhoods[0])  # Proportion of Choice 1 (e.g., 0)
        proportion_choice_2[t] = np.mean(choices_at_t == distinct_neighbourhoods[1])  # Proportion of Choice 2 (e.g., 1)

        std_choice_1[t] = np.std(choices_at_t == distinct_neighbourhoods[0])
        std_choice_2[t] = np.std(choices_at_t == distinct_neighbourhoods[1])
    
    return proportion_choice_1, proportion_choice_2, std_choice_1, std_choice_2

# Example data (replace this with your actual outputs_R3_c2 data)
# Assuming outputs_R3_c2 is a 2Dnp.array where rows are trials, columns are time steps
# For example, 100 trials, 500 time steps, with 0 and 1 representing two different choices
data =np.array(outputs_R3_c2)
# 1. Calculate the proportions of Choice 1 and Choice 2 at each time step
proportion_choice_1, proportion_choice_2, std_choice_1, std_choice_2 = calculate_choice_frequencies(data)


# 2. Plot the results
plt.figure(figsize=(18, 6))

# Plot the proportion of Choice 1 and Choice 2
plt.plot(proportion_choice_1, label='Proportion of Landscape Configuration 1', color='blue', linewidth=2)
plt.plot(proportion_choice_2, label='Proportion of Landscape Configuration 2', color='red', linewidth=2)

#plt.fill_between(range(489), proportion_choice_1 - std_choice_1, proportion_choice_1 + std_choice_1, color='blue', alpha=0.2)
#plt.fill_between(range(489), proportion_choice_2 - std_choice_2, proportion_choice_2 + std_choice_2, color='red', alpha=0.2)

# Add labels and title
plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Proportion of Trials', fontsize=14)
plt.title('Proportion of Choice 1 and Choice 2 Over Time (100 Trials)', fontsize=16)

# Add a legend
plt.legend(loc='best')
#
# Display the plot
plt.tight_layout()
plt.savefig('Aggregate_landscape_configuration_mimic_disorder_12_q_inhomo_v1.png')
plt.show()

# %%
data=outputs_R3_c2_2[13][0:349]
# Get the distinct neighbourhoods
distinct_neighbourhoods = get_distinct_neighbourhoods(data)

# Track when each neighbourhood appears
time_steps = find_neighbourhood_appearances(data, distinct_neighbourhoods)

# Separate out the time and labels for plotting
times = [t for t, label in time_steps]
labels = [label for t, label in time_steps]

# Plotting
plt.figure(figsize=(18, 6))
plt.plot(times, labels, marker='o', linestyle='-', markersize=8)

# Customize the plot
plt.xticks(times)  # Show time steps on x-axis
plt.yticks(list(set(labels)))  # Show neighbourhood labels (a, b, c, ...) on y-axis
plt.xlabel('Time')
plt.ylabel('Neighbourhood')
plt.title('Neighbourhoods over Time')
plt.grid(True)

# Show the plot
plt.show()

# Print the distinct neighbourhoods
print("Distinct Neighbourhoods:")
for i, neighbourhood in enumerate(distinct_neighbourhoods):
    print(f"{chr(97 + i)}: {neighbourhood}")
# Out:
# Distinct Neighbourhoods:
# a: [[ 0  1]
#  [10 11]
#  [ 2  3]
#  [ 6  7]
#  [ 4  5]
#  [ 8  9]]
# b: [[ 9 10]
#  [ 1  2]
#  [ 3  4]
#  [ 0 11]
#  [ 5  6]
#  [ 7  8]]

# %%
data =np.array(outputs_R3_c2_2)
# 1. Calculate the proportions of Choice 1 and Choice 2 at each time step
proportion_choice_1, proportion_choice_2, std_choice_1, std_choice_2 = calculate_choice_frequencies(data)


# 2. Plot the results
plt.figure(figsize=(18, 6))

# Plot the proportion of Choice 1 and Choice 2
plt.plot(proportion_choice_1, label='Proportion of Landscape Configuration 1', color='blue', linewidth=2)
plt.plot(proportion_choice_2, label='Proportion of Landscape Configuration 2', color='red', linewidth=2)

#plt.fill_between(range(489), proportion_choice_1 - std_choice_1, proportion_choice_1 + std_choice_1, color='blue', alpha=0.2)
#plt.fill_between(range(489), proportion_choice_2 - std_choice_2, proportion_choice_2 + std_choice_2, color='red', alpha=0.2)


# Add labels and title
plt.xlabel('Time Steps', fontsize=14)
plt.ylabel('Proportion of Trials', fontsize=14)
plt.title('Proportion of Choice 1 and Choice 2 Over Time (100 Trials)', fontsize=16)

# Add a legend
plt.legend(loc='best')
#
# Display the plot
plt.tight_layout()
plt.savefig('Aggregate_landscape_configuration_mimic_update_rule_12_q_inhomo_v1.png')
plt.show()

# %%
def compute_ensemble_average(dataset_for_one_rule):
    """
    Compute the ensemble average adjacency matrix from a list of datasets.
    """
    # Initialize adj_matrix_sum to None to indicate it's uninitialized
    adj_matrix_sum = None
    
    # Loop over all datasets and compute the adjacency matrix for each
    for data in dataset_for_one_rule:
        # Flatten the dataset into a list of tuples representing pairs
        edges = [tuple(sorted(pair)) for sublist in data for pair in sublist]
        
        # Count the number of times each node pair appears
        edge_weights = Counter(edges)
        #print(f'edgew:{edge_weights}')

        # Create a graph
        G = nx.Graph()

        # Add edges along with their weights
        for edge, weight in edge_weights.items():
            G.add_edge(edge[0], edge[1], weight=weight/len(data))

        # Get the edge weights
        weights = np.array([G[u][v]['weight'] for u, v in G.edges()])

        # Calculate the adjacency matrix for this dataset
        n_nodes = max(max(edge) for edge in edges) + 1
        adj_matrix = np.zeros((n_nodes, n_nodes))

        for edge, weight in edge_weights.items():
            adj_matrix[edge[0], edge[1]] = weight/len(data)
            adj_matrix[edge[1], edge[0]] = weight/len(data)
            
        # Check the row sums before averaging
        row_sums = adj_matrix.sum(axis=1)
        #print(f"RowS: {row_sums}")
        adj_matrix = np.round(adj_matrix, 2)
        #print(f"Adj: {adj_matrix}")

        # Initialize adj_matrix_sum on the first iteration
        if adj_matrix_sum is None:
            adj_matrix_sum = np.zeros_like(adj_matrix)
        
        # Accumulate the adjacency matrices
        adj_matrix_sum += adj_matrix
    ensemble_avg_matrix=adj_matrix_sum / len(dataset_for_one_rule)
    ensemble_avg_matrix = np.round(ensemble_avg_matrix, 2)
    # Compute the ensemble average
    return ensemble_avg_matrix

# %%
def visualize_network(adj_matrix, ax, title, pos, cmap):
    """
    Visualizes a network based on the provided adjacency matrix.
    """
    # Create a graph
    G = nx.from_numpy_array(adj_matrix)  # Use from_numpy_array instead of from_numpy_matrix

    # Normalize the weights for color mapping
    weights = np.array([G[u][v]['weight'] for u, v in G.edges()])
    norm = plt.Normalize(vmin=0, vmax=1)

    # Map edge weights to colors using the given colormap
    edge_colors = [cmap(norm(w)) for w in weights]

    # Scale edge thickness according to the weight (here using width factor for better visibility)
    #min_width = 0.5  # Minimum edge width (for visualization)
    #max_width = 5.0  # Maximum edge width (for visualization)
    #edge_widths = min_width + (weights - np.min(weights)) / (np.max(weights) - np.min(weights)) * (max_width - min_width)

    # Draw the graph with node labels
    nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=500,
            edge_color=edge_colors, width=3, ax=ax)

    # Draw edge labels to show weights
    nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): d['weight'] for u, v, d in G.edges(data=True)}, ax=ax)

    # Add a color bar to show the weight scale
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    #plt.colorbar(sm, ax=ax, label="Edge weight")

    # Add a title to each subplot
    ax.set_title(title,fontsize=14)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))

# Define a colormap and positions for nodes
cmap = cm.viridis
pos = nx.circular_layout(nx.from_numpy_array(compute_ensemble_average(outputs_R3_c2)))

# Call the visualize function
visualize_network(compute_ensemble_average(outputs_R3_c2), ax, "Network Visualization", pos, cmap)

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))

# Define a colormap and positions for nodes
cmap = cm.viridis
pos = nx.circular_layout(nx.from_numpy_array(compute_ensemble_average(outputs_R3_c2_2)))

# Call the visualize function
visualize_network(compute_ensemble_average(outputs_R3_c2_2), ax, "Network Visualization", pos, cmap)

# Show the plot
plt.show()

# %%
def extractable_work_of_one_trial(pops,trial):
    return np.array([measure.extractable_work_of_each_qubit_from_pops(p) for p in pops[trial]])

def extractable_work_of_all_trials(pops):
    ext_work_all = []
    for trial in range(100):
        ext_work_all.append(extractable_work_of_one_trial(pops,trial))
    return ext_work_all

# %%
ext_work_all_mimic_disorder_c2 = extractable_work_of_all_trials(pops_mimic_c2)

# %%
ext_work_all_mimic_disorder_c2_2 = extractable_work_of_all_trials(pops_mimic_c2_2)

# %%
def ensemble_averaged_one_point_measures_mean_std(datasets):
    # Assuming datasets is a list of 100 datasets, where each dataset is a 2Dnp.array of shape (100, N)
    # Stack datasets into a 3Dnp.array
    stacked_data = np.stack(datasets)  # Shape (100, 100, N)

    # Take the ensemble average along the first axis (averaging over all datasets)
    ensemble_average = np.mean(stacked_data, axis=0)  # Shape (100, N)

    # Calculate the standard deviation along the first axis
    ensemble_std = np.std(stacked_data, axis=0) 
    return (ensemble_average, ensemble_std)

# %%
pops_mimic_c2_ens_avg=ensemble_averaged_one_point_measures_mean_std(pops_mimic_c2)

# %%
pops_mimic_c2_ens_avg_2=ensemble_averaged_one_point_measures_mean_std(pops_mimic_c2_2)

# %%
ext_work_of_ens_avg_mimic_disorder = extractable_work_of_one_trial(pops_mimic_c2_ens_avg,0)

# %%
ext_work_of_ens_avg_mimic_disorder_c2_2 = extractable_work_of_one_trial(pops_mimic_c2_ens_avg_2,0)

# %%
def change_in_ext_work(ext_work_one_trial):
    return np.diff(ext_work_one_trial,axis = 0)

def change_in_ext_work_all_trials(ext_work_all_trial):
    change_in_ext_all =[]
    for trial in range(100):
        change_in_ext_all.append(np.diff(ext_work_all_trial[trial],axis = 0))
    return change_in_ext_all

# %%
ens_avg_change_in_ext_work_mimic_disorder_c2=ensemble_averaged_one_point_measures_mean_std(change_in_ext_work_all_trials(ext_work_all_mimic_disorder_c2))[0]

# %%
ens_avg_change_in_ext_work_mimic_disorder_c2_2=ensemble_averaged_one_point_measures_mean_std(change_in_ext_work_all_trials(ext_work_all_mimic_disorder_c2_2))[0]

# %%
change_in_ext_work_ens_avg_mimic_disorder_c2=change_in_ext_work(ext_work_of_ens_avg_mimic_disorder_c2)

# %%
change_in_ext_work_ens_avg_mimic_disorder_c2_2=change_in_ext_work(ext_work_of_ens_avg_mimic_disorder_c2_2)

# %%
vmin = 0  # Replace with your desired minimum value
vmax = 1  # Replace with your desired maximum value
norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
conn='C2'
datas=[change_in_ext_work_ens_avg_mimic_disorder_c2]

binary_datas=[]
for data in datas:
    change_per_timestep=[]
    for data_timestep in data:
        data_timestep_peq_q=[]
        for change_q_index in data_timestep:
            if change_q_index<0:
                change_q_index=0
            elif change_q_index>0:
                change_q_index=1
            data_timestep_peq_q.append(change_q_index)
        change_per_timestep.append(data_timestep_peq_q)
    binary_datas.append(change_per_timestep)

for data in binary_datas:

    # Create a new figure with a specified size
    plt.figure(figsize=(50, 5))  # Adjust as necessary
    
    # Rotate the data by 90 degrees counterclockwise
    rotated_data = np.rot90(data[0:499])

    # Display the rotated data
    img = plt.imshow(rotated_data, interpolation='none', norm=norm, aspect='auto')

    # Add a colorbar
    cbar = plt.colorbar(img, orientation='horizontal', pad=0.05)
    cbar.ax.tick_params(labelsize=10)  # Set colorbar tick label size

    plt.title(f'Plot for C2', fontsize=24)  # Optional: Add a title for clarity
    #plt.savefig(f'change_in_ext_work_ens_avg if positive swatch of network {num}q_conn_{conn}_{dataset_label}.pdf', format='pdf', bbox_inches='tight')
    plt.show()

# %%
vmin = 0  # Replace with your desired minimum value
vmax = 1  # Replace with your desired maximum value
norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
conn='C2'
datas=[change_in_ext_work_ens_avg_mimic_disorder_c2_2]

binary_datas=[]
for data in datas:
    change_per_timestep=[]
    for data_timestep in data:
        data_timestep_peq_q=[]
        for change_q_index in data_timestep:
            if change_q_index<0:
                change_q_index=0
            elif change_q_index>0:
                change_q_index=1
            data_timestep_peq_q.append(change_q_index)
        change_per_timestep.append(data_timestep_peq_q)
    binary_datas.append(change_per_timestep)

for data in binary_datas:

    # Create a new figure with a specified size
    plt.figure(figsize=(50, 5))  # Adjust as necessary
    
    # Rotate the data by 90 degrees counterclockwise
    rotated_data = np.rot90(data[0:499])

    # Display the rotated data
    img = plt.imshow(rotated_data, interpolation='none', norm=norm, aspect='auto')

    # Add a colorbar
    cbar = plt.colorbar(img, orientation='horizontal', pad=0.05)
    cbar.ax.tick_params(labelsize=10)  # Set colorbar tick label size

    plt.title(f'Plot for C2', fontsize=24)  # Optional: Add a title for clarity
    #plt.savefig(f'change_in_ext_work_ens_avg if positive swatch of network {num}q_conn_{conn}_{dataset_label}.pdf', format='pdf', bbox_inches='tight')
    plt.show()

# %%
vmin = 0  # Replace with your desired minimum value
vmax = 8  # Replace with your desired maximum value
norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
datas=[ens_avg_change_in_ext_work_mimic_disorder_c2]

binary_datas=[]
for data in datas:
    change_per_timestep=[]
    for data_timestep in data:
        data_timestep_peq_q=[]
        for change_q_index in data_timestep:
            if change_q_index<0:
                change_q_index=0
            elif change_q_index>0:
                change_q_index=1
            data_timestep_peq_q.append(change_q_index)
        change_per_timestep.append(data_timestep_peq_q)
    binary_datas.append(change_per_timestep)

for data in binary_datas:

    data = np.sum(data, axis=1)
    # Create a line plot
    plt.figure(figsize=(20, 6))
    plt.plot(data, marker='o', linestyle='-', color='b')  # Plot as a line with markers
    plt.title("Line Plot of 499 Numbers")
    plt.xlabel("Index")
    plt.ylabel("Value")
    plt.grid(True)
    plt.show()

# %%
vmin = 0  # Replace with your desired minimum value
vmax = 8  # Replace with your desired maximum value
norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
datas=[ens_avg_change_in_ext_work_mimic_disorder_c2_2]

binary_datas=[]
for data in datas:
    change_per_timestep=[]
    for data_timestep in data:
        data_timestep_peq_q=[]
        for change_q_index in data_timestep:
            if change_q_index<0:
                change_q_index=0
            elif change_q_index>0:
                change_q_index=1
            data_timestep_peq_q.append(change_q_index)
        change_per_timestep.append(data_timestep_peq_q)
    binary_datas.append(change_per_timestep)

for data in binary_datas:

    data = np.sum(data, axis=1)
    # Create a line plot
    plt.figure(figsize=(20, 6))
    plt.plot(data, marker='o', linestyle='-', color='b')  # Plot as a line with markers
    plt.title("Line Plot of 499 Numbers")
    plt.xlabel("Index")
    plt.ylabel("Value")
    plt.grid(True)
    plt.show()

# %%
#where list of lists is change in ext work for one trial
#index is qubit index
#Gives a list where first element is the total number of positive steps and the second is a list of when/length of the positive change
def count_positive_steps(list_of_lists, index):
    total_positive_steps = 0
    consecutive_positive_steps = 0
    consecutive_lengths = []  # List to store lengths of consecutive positive sequences
    for lst in list_of_lists:
        if lst[index] > 0:
            total_positive_steps += 1
            consecutive_positive_steps += 1
        else:
            consecutive_lengths.append(consecutive_positive_steps)  # Record length of consecutive positive sequence
            consecutive_positive_steps = 0  # Reset consecutive count if value becomes non-positive
            
    # Add the last consecutive count if the list ends with a positive value
    if consecutive_positive_steps > 0:
        consecutive_lengths.append(consecutive_positive_steps)
        
    return total_positive_steps, consecutive_lengths

# %%
def tally_elements(lst):
    tally = {}
    for element in lst:
        tally[element] = tally.get(element, 0) + 1
    return tally

#Plots histogram using above tally dictionary
def plot_histogram(ax, tally, label):
    elements = list(tally.keys())
    counts = list(tally.values())

    ax.bar(elements, counts)
    ax.set_xlabel('Element')
    ax.set_ylabel('Frequency')
    ax.set_title(label)
    ax.legend(label)

#Get the total number of positive steps per qubit on the network as a list
def Num_steps_positive(change_in_ex_work):
    Num_steps_positive=[]
    for qubit_index in range(8):
        Num_steps_positive.append(count_positive_steps(change_in_ex_work,qubit_index)[0])
    return Num_steps_positive

#Get the list of when positive changes occur per qubit on the network as a list
def list_of_consecutive_positive_steps(change_in_ex_work):
    sum=[0]
    for qubit_id in range(8):
        sum = sum+count_positive_steps(change_in_ex_work,qubit_id)[1]
    return sum

# %%
#Gives the average length of interaval for which the qubit has positive change; does for each qubit and returns a list
def average_time_step_Q_positive(num_qubits,changein_Wex):
    average_time_positive = []
    for qubit_index in range(num_qubits):
        average_time_positive.append(np.mean(count_positive_steps(changein_Wex, qubit_index)[1]))
    return average_time_positive
    
#takes in a dictionary
def avg_time_step_positive(tally):
    num=0
    denom=0
    for key,values in tally.items():
        num = values*key+num
        denom=values+denom
    return num/denom

# %%
#examples
average_time_step_Q_positive(num,change_in_ext_work_ens_avg_mimic_disorder_c2)
# Out:
# [0.9266409266409267,
#  0.8901515151515151,
#  0.996,
#  0.9083969465648855,
#  0.9305019305019305,
#  0.9230769230769231,
#  0.9192307692307692,
#  0.8759398496240601,
#  0.9305019305019305,
#  0.9157088122605364,
#  0.94921875,
#  0.8973384030418251]

# %%
#get average of the cumulative positive change in extractable work since this is the value you can extract at any point from the landscape as resource
def replace_negatives_with_zero(lst):
    for sublist in lst:
        for i in range(len(sublist)):
            if sublist[i] < 0:
                sublist[i] = 0
    return lst

def replace_consecutive_positives_with_cumulative_sum(list_of_lists):
    lst = [list(column) for column in zip(*list_of_lists)]
    for sublist in lst:
        cumulative_sum = 0
        consecutive_positive_count = 0
        for i in range(len(sublist)):
            if sublist[i] > 0:
                cumulative_sum += sublist[i]
                consecutive_positive_count += 1
                if i == len(sublist) - 1 or sublist[i + 1] == 0:
                    if consecutive_positive_count > 1:
                        for j in range(i - consecutive_positive_count + 1, i + 1):
                            sublist[j] = 0
                        sublist[i] = cumulative_sum
                    cumulative_sum = 0
                    consecutive_positive_count = 0
            else:
                cumulative_sum = 0
                consecutive_positive_count = 0
    return lst

def list_of_consec_positive_steps_no_zeros(change_in):
    listt=[]
    for ele in list_of_consecutive_positive_steps(change_in):
        if ele != 0:
            listt.append(ele)
    return listt

def consecutive_positives_with_cumulative_sum_no_zeores(change_in):
    list2=[]
    for ele in np.array(replace_consecutive_positives_with_cumulative_sum(replace_negatives_with_zero(change_in))).flatten():
        if ele!=0:
            list2.append(ele)
    return list2

# %%
list_of_consec_positive_steps_no_zeros(change_in_ext_work_ens_avg_mimic_disorder_c2)
#More examples
consecutive_positives_with_cumulative_sum_no_zeores(change_in_ext_work_ens_avg_mimic_disorder_c2)
# Out:
# [0.0012930299322907628,
#  0.0001426704991000501,
#  6.26131312945608e-05,
#  4.52310422134279e-05,
#  3.781204386183126e-05,
#  2.6499025512093175e-05,
#  1.264693939725572e-05,
#  2.879567914632273e-07,
#  4.2552721178364906e-05,
#  4.5442397347751495e-06,
#  2.49801893516325e-05,
#  7.82086708493248e-06,
#  1.1498528950586557e-06,
#  7.456889351325994e-08,
#  1.378577995726988e-07,
#  1.222247428094208e-07,
#  1.645702315366422e-08,
#  8.53852831430043e-07,
#  7.869024902790227e-08,
#  1.1369548652955178e-05,
#  1.4935549153449553e-05,
#  5.976526056799476e-06,
#  3.915846467459138e-06,
#  3.001274761090837e-05,
#  1.1005514481399785e-05,
#  8.661983248599469e-06,
#  1.460167807351754e-06,
#  1.710391087669362e-06,
#  4.223767005156921e-05,
#  5.177823565600019e-05,
#  1.3703220125802515e-06,
#  3.861852625875694e-06,
#  1.2814137920578288e-05,
#  5.205920351751572e-06,
#  2.233665713261688e-06,
#  4.4894567802688196e-05,
#  1.883788222373122e-05,
#  2.1368949663745906e-06,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
#data1 = np.array(consecutive_positives_with_cumulative_sum_no_zeores(ens_avg_change_in_ext_work_random_c2))
#data2 = np.array(consecutive_positives_with_cumulative_sum_no_zeores(ens_avg_change_in_ext_work_greedy_c2))
data3 = np.array(consecutive_positives_with_cumulative_sum_no_zeores(ens_avg_change_in_ext_work_mimic_disorder_c2))  # Dataset 3
#data4 = np.array(consecutive_positives_with_cumulative_sum_no_zeores(ens_avg_change_in_ext_work_landscape_maximizes_c2))
#data5 = np.array(consecutive_positives_with_cumulative_sum_no_zeores(ens_avg_change_in_ext_work_strongest_maximizes_c2))
# Combine all datasets into onenp.array
all_data = np.concatenate([data3])

# Fit a MinMaxScaler using the combined data
scaler = MinMaxScaler()
scaler.fit(all_data.reshape(-1, 1))  # Fit to the combined data

# Normalize each dataset using the same min-max values
#data1_normalized = scaler.transform(data1.reshape(-1, 1)).flatten()
#data2_normalized = scaler.transform(data2.reshape(-1, 1)).flatten()
data3_normalized = scaler.transform(data3.reshape(-1, 1)).flatten()
##data4_normalized = scaler.transform(data4.reshape(-1, 1)).flatten()
#data5_normalized = scaler.transform(data5.reshape(-1, 1)).flatten()

# Plot the normalized datasets
plt.figure(figsize=(10, 6))
#plt.scatter(np.arange(len(data1_normalized)), data1_normalized, color='blue', label='Dataset 1 (Normalized)', alpha=0.5)
#plt.scatter(np.arange(len(data2_normalized)), data2_normalized, color='green', label='Dataset 2 (Normalized)', alpha=0.5)
plt.scatter(np.arange(len(data3_normalized)), data3_normalized, color='red', label='Dataset 3 (Normalized)', alpha=0.5)
#plt.scatter(np.arange(len(data4_normalized)), data4_normalized, color='purple', label='Dataset 4 (Normalized)', alpha=0.5)
#plt.scatter(np.arange(len(data5_normalized)), data5_normalized, color='orange', label='Dataset 5 (Normalized)', alpha=0.5)

# Add labels and title
plt.title("Scatter Plot of 5 Datasets")
plt.xlabel("Index")
plt.ylabel("Value")

# Add a legend to differentiate the datasets
plt.legend()

# Show the plot
plt.show()

# %%
def average_ex_resource_landscape(change_in_ex_work):
    means=[]
    for qubit in range(8):
        means.append(np.mean(replace_consecutive_positives_with_cumulative_sum(replace_negatives_with_zero(change_in_ex_work))[qubit]))
    return np.mean(means)

def average_cumulative_Wex(num_qubits,changein_Wex):
    average_time_positive = []
    for qubit_index in range(num_qubits):
        average_time_positive.append(np.mean(count_positive_steps(changein_Wex, qubit_index)[1]))
    return average_time_positive
    
def total_wex(num_qubits,changein_Wex):
    total_wex = []
    for qubit_index in range(num_qubits):
        changein_Wex[0:99,qubit_index]
        total_wex.append(sum(changein_Wex[0:99,qubit_index]))
    return total_wex

# %%
#Num_steps_positive_random = Num_steps_positive(ens_avg_change_in_ext_work_random_c4)
#Num_steps_positive_greedy = Num_steps_positive(ens_avg_change_in_ext_work_greedy_c4)
Num_steps_positive_mimic = Num_steps_positive(ens_avg_change_in_ext_work_mimic_disorder_c2)
Num_steps_positive_mimic_2 = Num_steps_positive(ens_avg_change_in_ext_work_mimic_disorder_c2_2)

#Num_steps_positive_landmax = Num_steps_positive(ens_avg_change_in_ext_work_landscape_maximizes_c4)
#Num_steps_positive_smax = Num_steps_positive(ens_avg_change_in_ext_work_strongest_maximizes_c4)

        
#tally_random=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_random_c4))
#tally_greedy=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_greedy_c4))
#tally_landmax=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_landscape_maximizes_c4))
tally_mimic=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_mimic_disorder_c2))
tally_mimic_2=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_mimic_disorder_c2_2))

#tally_smax=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_strongest_maximizes_c4))

        
#del tally_landmax[0]
#del tally_random[0]
#del tally_greedy[0]
del tally_mimic[0]
del tally_mimic_2[0]

#del tally_smax[0]
    
        
fig, axs = plt.subplots(1, 5, figsize=(15, 5))
        
#plot_histogram(axs[0], tally_random, 'R1 ')
#plot_histogram(axs[1], tally_greedy, 'R2')
plot_histogram(axs[1], tally_mimic_2, 'R3')
plot_histogram(axs[2], tally_mimic, 'R3d')
#plot_histogram(axs[3], tally_landmax, 'R4')
#plot_histogram(axs[4], tally_smax, 'R5')

#plt.savefig('histogram_freq_temp_var_c4_therm.png')

plt.tight_layout()
#plt.savefig(f'Histogram for ens_avg change_in_ext_work {num}q_conn_c4_{dataset_label}.pdf', format='pdf', bbox_inches='tight')

plt.show()
        
fig, ax = plt.subplots(figsize=(10, 6))
        
# Call plot_histogram for each dataset with the desired color
#plot_histogram(ax, tally_random, 'R1')
#plot_histogram(ax, tally_greedy, 'R2')
plot_histogram(ax, tally_mimic_2, 'R3')
plot_histogram(ax, tally_mimic, 'R3d')
#plot_histogram(ax, tally_landmax, 'R4')
#plot_histogram(ax, tally_smax, 'R5')


        
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Comparison of Tally Tables')
        
# Show legend
plt.legend()
        
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Num_steps_positive_random = Num_steps_positive(ens_avg_change_in_ext_work_random_c2)
#Num_steps_positive_greedy = Num_steps_positive(ens_avg_change_in_ext_work_greedy_c2)
Num_steps_positive_mimic = Num_steps_positive(ens_avg_change_in_ext_work_mimic_disorder_c2)
Num_steps_positive_mimic_2 = Num_steps_positive(ens_avg_change_in_ext_work_mimic_disorder_c2_2)

##Num_steps_positive_landmax = Num_steps_positive(ens_avg_change_in_ext_work_landscape_maximizes_c2)
#Num_steps_positive_smax = Num_steps_positive(ens_avg_change_in_ext_work_strongest_maximizes_c2)

        
#ally_random=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_random_c2))
#tally_greedy=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_greedy_c2))
#tally_landmax=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_landscape_maximizes_c2))
tally_mimic_2=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_mimic_disorder_c2_2))

tally_mimic=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_mimic_disorder_c2))
#tally_smax=tally_elements(list_of_consecutive_positive_steps(ens_avg_change_in_ext_work_strongest_maximizes_c2))

        
#del tally_landmax[0]
#del tally_random[0]
#del tally_greedy[0]
del tally_mimic_2[0]

del tally_mimic[0]
#del tally_smax[0]
    
        
fig, axs = plt.subplots(1, 5, figsize=(15, 5))
        
#plot_histogram(axs[0], tally_random, 'R1 ')
#plot_histogram(axs[1], tally_greedy, 'R2')
plot_histogram(axs[1], tally_mimic_2, 'R3')

plot_histogram(axs[2], tally_mimic, 'R3d')
#plot_histogram(axs[3], tally_landmax, 'R4')
#plot_histogram(axs[4], tally_smax, 'R5')

#plt.savefig('histogram_freq_temp_var_c4_therm.png')

plt.tight_layout()
#plt.savefig(f'Histogram for ens_avg change_in_ext_work {num}q_conn_c2_{dataset_label}.pdf', format='pdf', bbox_inches='tight')

plt.show()
        
fig, ax = plt.subplots(figsize=(10, 6))
        
# Call plot_histogram for each dataset with the desired color
#plot_histogram(ax, tally_random, 'R1')
#plot_histogram(ax, tally_greedy, 'R2')
plot_histogram(ax, tally_mimic_2, 'R3d')

plot_histogram(ax, tally_mimic, 'R3d')
#plot_histogram(ax, tally_landmax, 'R4')
#plot_histogram(ax, tally_smax, 'R5')


        
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Comparison of Tally Tables')
        
# Show legend
plt.legend()
        
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
